# %%
from dotenv import load_dotenv, find_dotenv
from typing import Dict
import json
import os
import requests

# %%
def load_emaps_api_key():
    load_dotenv(find_dotenv())
    api_key = os.getenv('ELECTRICITY_MAPS_API_KEY')
    if not api_key:
        print('No API key found in environment')
    else:
        return api_key

# %% [markdown]
# ## Sample: Latest Carbon intensity in Glasgow, Scotland

# %%
coordinates = {
    "lat": 55.8287,
    "lon": -4.2611
}
url= f"https://api.electricitymap.org/v3/carbon-intensity/latest?lat={coordinates['lat']}&lon={coordinates['lon']}"
print("Endpoint: " + str(url))
# Out:
# Endpoint: https://api.electricitymap.org/v3/carbon-intensity/latest?lat=55.8287&lon=-4.2611

# %%
request = requests.get(url, headers={'auth-token': load_emaps_api_key()})

# %%
json.loads(request.content)
# Out:
# {'zone': 'GB',
#  'carbonIntensity': 234,
#  'datetime': '2024-11-10T22:00:00.000Z',
#  'updatedAt': '2024-11-10T21:43:10.048Z',
#  'createdAt': '2024-11-07T22:45:16.884Z',
#  'emissionFactorType': 'lifecycle',
#  'isEstimated': True,
#  'estimationMethod': 'TIME_SLICER_AVERAGE'}

# %% [markdown]
# ## Live power breakdown within Glasgow, Scotland

# %%
url = f"https://api.electricitymap.org/v3/power-breakdown/latest?lat={coordinates['lat']}&lon={coordinates['lon']}"
print("Endpoint: " + str(url))
# Out:
# Endpoint: https://api.electricitymap.org/v3/power-breakdown/latest?lat=55.8287&lon=-4.2611

# %%
request = requests.get(url, headers={'auth-token': load_emaps_api_key()})
power_breakdown = json.loads(request.content)

# %%
power_breakdown
# Out:
# {'zone': 'GB',
#  'datetime': '2024-11-10T22:00:00.000Z',
#  'updatedAt': '2024-11-10T21:43:10.048Z',
#  'createdAt': '2024-11-07T22:45:16.884Z',
#  'powerConsumptionBreakdown': {'nuclear': 5364,
#   'geothermal': 0,
#   'biomass': 3034,
#   'coal': 0,
#   'wind': 8795,
#   'solar': 0,
#   'hydro': 1172,
#   'gas': 13258,
#   'oil': 2,
#   'unknown': 181,
#   'hydro discharge': 66,
#   'battery discharge': 0},
#  'powerProductionBreakdown': {'nuclear': 4779,
#   'geothermal': None,
#   'biomass': 3038,
#   'coal': 0,
#   'wind': 8794,
#   'solar': 0,
#   'hydro': 127,
#   'gas': 13248,
#   'oil': 0,
#   'unknown': 160,
#   'hydro discharge': -129,
#   'battery discharge': None},
#  'powerImportBreakdown': {'BE': 107,
#   'FR': 1624,
#   'IE': 0,
#   'IM': 0,
#   'NL': 0,
#   'GB-NIR': 0,
#   'GB-ORK': 18,
#   'NO-NO2': 1448},
#  'powerExportBreakdown': {'BE': 0,
#   'FR': 0,
#   'IE': 530,
#   'IM': 31,
#   'NL': 424,
#   'GB-NIR': 357,
#   'GB-ORK': 0,
#   'NO-NO2': 0},
#  'fossilFreePercentage': 58,
#  'renewablePercentage': 41,
#  'powerConsumptionTotal': 31871,
#  'powerProductionTotal': 30145,
#  'powerImportTotal': 3197,
#  'powerExportTotal': 1342,
#  'isEstimated': True,
#  'estimationMethod': 'TIME_SLICER_AVERAGE'}

# %%
total_consumption = power_breakdown['powerConsumptionTotal']
total_consumption
# Out:
# 31871

# %%
power_consumption_pct = {
    k:v/total_consumption*100
    for k,v
    in power_breakdown['powerConsumptionBreakdown'].items()
}

# %%
power_consumption_pct
# Out:
# {'nuclear': 16.830347337705124,
#  'geothermal': 0.0,
#  'biomass': 9.519625992281384,
#  'coal': 0.0,
#  'wind': 27.595619842490038,
#  'solar': 0.0,
#  'hydro': 3.677324213234602,
#  'gas': 41.59894575005491,
#  'oil': 0.006275297292209219,
#  'unknown': 0.5679144049449343,
#  'hydro discharge': 0.20708481064290418,
#  'battery discharge': 0.0}

# %% [markdown]
# ### Helper function

# %%
def get_latest_power_breakdown(coordinates: Dict[str, float]):
    assert 'lat' in coordinates
    assert 'lon' in coordinates
    
    url = f"https://api.electricitymap.org/v3/power-breakdown/latest?lat={coordinates['lat']}&lon={coordinates['lon']}"
    request = requests.get(url, headers={'auth-token': load_emaps_api_key()})
    power_breakdown = json.loads(request.content)
    
    total_consumption = power_breakdown['powerConsumptionTotal']
    power_consumption_pct = {
        k:v/total_consumption*100
        for k,v
        in power_breakdown['powerConsumptionBreakdown'].items()
    }
    return power_consumption_pct

# %%
get_latest_power_breakdown(coordinates)
# Out:
# {'nuclear': 16.830347337705124,
#  'geothermal': 0.0,
#  'biomass': 9.519625992281384,
#  'coal': 0.0,
#  'wind': 27.595619842490038,
#  'solar': 0.0,
#  'hydro': 3.677324213234602,
#  'gas': 41.59894575005491,
#  'oil': 0.006275297292209219,
#  'unknown': 0.5679144049449343,
#  'hydro discharge': 0.20708481064290418,
#  'battery discharge': 0.0}

# %% [markdown]
# ### Processing AWS datacenters

# %%
aws_regions = []

with open('aws_datacenters', 'r') as f:
    data = f.readlines()

for region in data:
    region = region.replace('\n', '').strip()
    parts = region.split(';')
    if len(parts) != 4:
        print('Unable to parse line', parts, 'Skipping...')
        continue
    aws_regions.append({
        'region': parts[0],
        'name': parts[1],
        'lat': parts[2],
        'lon': parts[3],
    })
# Out:
# Unable to parse line [''] Skipping...

# %%
aws_regions[:6]
# Out:
# [{'region': 'us-east-1', 'name': 'Virginia', 'lat': '38.13', 'lon': '-78.45'},
#  {'region': 'us-east-2', 'name': 'Ohio', 'lat': '39.96', 'lon': '-83'},
#  {'region': 'eu-north-1', 'name': 'Stockholm', 'lat': '59.25', 'lon': '17.81'},
#  {'region': 'eu-south-1', 'name': 'Milan', 'lat': '45.43', 'lon': '9.29'},
#  {'region': 'us-west-1',
#   'name': 'California',
#   'lat': '37.35',
#   'lon': '-121.96'},
#  {'region': 'us-west-2', 'name': 'Oregon', 'lat': '46.15', 'lon': '-123.88'}]

# %% [markdown]
# ## Try coordinates of an AWS dataserver

# %%
print(aws_regions[0])
get_latest_power_breakdown(aws_regions[0])
# Out:
# {'region': 'us-east-1', 'name': 'Virginia', 'lat': '38.13', 'lon': '-78.45'}
# {'nuclear': 33.115585064610556,
#  'geothermal': 0.0,
#  'biomass': 0.0,
#  'coal': 10.406701411199162,
#  'wind': 9.643987530044502,
#  'solar': 0.001189881249851265,
#  'hydro': 2.9782727683777157,
#  'gas': 42.71435710716071,
#  'oil': 0.5080792936864901,
#  'unknown': 0.6318269436710217,
#  'hydro discharge': 0.0,
#  'battery discharge': 0.0}

# %%
print(aws_regions[2])
get_latest_power_breakdown(aws_regions[2])
# Out:
# {'region': 'eu-north-1', 'name': 'Stockholm', 'lat': '59.25', 'lon': '17.81'}
# {'nuclear': 70.35670356703567,
#  'geothermal': 0.0,
#  'biomass': 0.0,
#  'coal': 0.0,
#  'wind': 2.127921279212792,
#  'solar': 0.0,
#  'hydro': 19.82779827798278,
#  'gas': 0.0,
#  'oil': 0.0,
#  'unknown': 7.687576875768758,
#  'hydro discharge': 0.0,
#  'battery discharge': 0.0}

# %% [markdown]
# ## Merge the regions and power breakdown datasets

# %%
data = []

# %%
for region in aws_regions:
    power_breakdown = get_latest_power_breakdown(region)
    
    # Determine highest contributing energy source
    highest_source = max(power_breakdown, key=power_breakdown.get)

    region.update(power_breakdown)
    region['highest_source'] = highest_source
    
    data.append(region)

# %%
data
# Out:
# [{'region': 'us-east-1',
#   'name': 'Virginia',
#   'lat': '38.13',
#   'lon': '-78.45',
#   'nuclear': 33.115585064610556,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 10.406701411199162,
#   'wind': 9.643987530044502,
#   'solar': 0.001189881249851265,
#   'hydro': 2.9782727683777157,
#   'gas': 42.71435710716071,
#   'oil': 0.5080792936864901,
#   'unknown': 0.6318269436710217,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'us-east-2',
#   'name': 'Ohio',
#   'lat': '39.96',
#   'lon': '-83',
#   'nuclear': 33.115585064610556,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 10.406701411199162,
#   'wind': 9.643987530044502,
#   'solar': 0.001189881249851265,
#   'hydro': 2.9782727683777157,
#   'gas': 42.71435710716071,
#   'oil': 0.5080792936864901,
#   'unknown': 0.6318269436710217,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'eu-north-1',
#   'name': 'Stockholm',
#   'lat': '59.25',
#   'lon': '17.81',
#   'nuclear': 70.35670356703567,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 0.0,
#   'wind': 2.127921279212792,
#   'solar': 0.0,
#   'hydro': 19.82779827798278,
#   'gas': 0.0,
#   'oil': 0.0,
#   'unknown': 7.687576875768758,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'nuclear'},
#  {'region': 'eu-south-1',
#   'name': 'Milan',
#   'lat': '45.43',
#   'lon': '9.29',
#   'nuclear': 0.0,
#   'geothermal': 0.0,
#   'biomass': 3.7895546792343944,
#   'coal': 0.0,
#   'wind': 0.9137251130133692,
#   'solar': 0.0,
#   'hydro': 41.781283062421856,
#   'gas': 44.282004424353175,
#   'oil': 0.30778109069924015,
#   'unknown': 7.723381744734057,
#   'hydro discharge': 1.2118880446282583,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'us-west-1',
#   'name': 'California',
#   'lat': '37.35',
#   'lon': '-121.96',
#   'nuclear': 10.569550930996714,
#   'geothermal': 3.7075575027382257,
#   'biomass': 1.8838992332968236,
#   'coal': 0.0,
#   'wind': 1.7634173055859803,
#   'solar': 61.5881708652793,
#   'hydro': 3.3570646221248635,
#   'gas': 17.130339539978095,
#   'oil': 0.0,
#   'unknown': 0.0,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'solar'},
#  {'region': 'us-west-2',
#   'name': 'Oregon',
#   'lat': '46.15',
#   'lon': '-123.88',
#   'nuclear': 0.0,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 0.0,
#   'wind': 0.0,
#   'solar': 27.235213204951858,
#   'hydro': 1.2379642365887207,
#   'gas': 65.19944979367263,
#   'oil': 0.0,
#   'unknown': 6.189821182943604,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'eu-west-1',
#   'name': 'Ireland',
#   'lat': '53',
#   'lon': '-8',
#   'nuclear': 1.2539184952978055,
#   'geothermal': 0.0,
#   'biomass': 3.787878787878788,
#   'coal': 14.132706374085686,
#   'wind': 7.915360501567398,
#   'solar': 0.0,
#   'hydro': 6.112852664576803,
#   'gas': 62.85266457680251,
#   'oil': 3.787878787878788,
#   'unknown': 0.13061650992685475,
#   'hydro discharge': 0.026123301985370953,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'eu-west-2',
#   'name': 'London',
#   'lat': '51',
#   'lon': '-0.1',
#   'nuclear': 16.830347337705124,
#   'geothermal': 0.0,
#   'biomass': 9.519625992281384,
#   'coal': 0.0,
#   'wind': 27.595619842490038,
#   'solar': 0.0,
#   'hydro': 3.677324213234602,
#   'gas': 41.59894575005491,
#   'oil': 0.006275297292209219,
#   'unknown': 0.5679144049449343,
#   'hydro discharge': 0.20708481064290418,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'eu-west-3',
#   'name': 'Paris',
#   'lat': '48.86',
#   'lon': '2.35',
#   'nuclear': 74.66561618234454,
#   'geothermal': 0.0,
#   'biomass': 1.6526805672615341,
#   'coal': 0.0,
#   'wind': 4.043753893510205,
#   'solar': 0.0,
#   'hydro': 10.22023525962842,
#   'gas': 8.340356920370844,
#   'oil': 0.19421745025468137,
#   'unknown': 0.0,
#   'hydro discharge': 0.8684818058558393,
#   'battery discharge': 0.014657920773938219,
#   'highest_source': 'nuclear'},
#  {'region': 'eu-central-1',
#   'name': 'Frankfurt',
#   'lat': '50',
#   'lon': '8',
#   'nuclear': 0.8035549825013816,
#   'geothermal': 0.10130779149014552,
#   'biomass': 13.370326026892615,
#   'coal': 42.314422545588506,
#   'wind': 10.476146620003684,
#   'solar': 0.027629397679130592,
#   'hydro': 5.376220298397495,
#   'gas': 25.83118438018051,
#   'oil': 0.8104623319211641,
#   'unknown': 0.722969239270584,
#   'hydro discharge': 0.16577638607478357,
#   'battery discharge': 0.0,
#   'highest_source': 'coal'},
#  {'region': 'sa-east-1',
#   'name': 'Sao Paulo',
#   'lat': '-23.34',
#   'lon': '-46.38',
#   'nuclear': 1.6261364476310147,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 0.0,
#   'wind': 7.568926010791632,
#   'solar': 3.7401138295513343,
#   'hydro': 69.13790129844531,
#   'gas': 0.0,
#   'oil': 0.0,
#   'unknown': 17.926922413580705,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'hydro'},
#  {'region': 'ap-southeast-1',
#   'name': 'Singapore',
#   'lat': '1.37',
#   'lon': '103.8',
#   'nuclear': 0.0,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 0.0,
#   'wind': 0.0,
#   'solar': 0.0,
#   'hydro': 0.0,
#   'gas': 97.60831889081456,
#   'oil': 0.0,
#   'unknown': 2.3916811091854417,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'ap-southeast-2',
#   'name': 'Sydney',
#   'lat': '-33.86',
#   'lon': '151.2',
#   'nuclear': 0.0,
#   'geothermal': 0.0,
#   'biomass': 0.3157172271791352,
#   'coal': 49.00480439258751,
#   'wind': 12.875772134522991,
#   'solar': 35.59368565545642,
#   'hydro': 1.702127659574468,
#   'gas': 0.30199039121482496,
#   'oil': 0.0,
#   'unknown': 0.0,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.2196293754289636,
#   'highest_source': 'coal'},
#  {'region': 'ap-northeast-1',
#   'name': 'Tokyo',
#   'lat': '35.41',
#   'lon': '139.42',
#   'nuclear': 0.14318803958728155,
#   'geothermal': 0.10528532322594232,
#   'biomass': 1.448726047588966,
#   'coal': 39.2966940408507,
#   'wind': 0.29901031796167615,
#   'solar': 0.34112444725205304,
#   'hydro': 5.980206359233523,
#   'gas': 44.173510212676355,
#   'oil': 3.9839966308696564,
#   'unknown': 0.22741629816803538,
#   'hydro discharge': 3.99663086965677,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'ap-northeast-2',
#   'name': 'Seoul',
#   'lat': '37.56',
#   'lon': '126.98',
#   'nuclear': 37.77854791197366,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 20.348293190088373,
#   'wind': 0.0,
#   'solar': 3.482931900883729,
#   'hydro': 0.31883555709582395,
#   'gas': 33.7584474094611,
#   'oil': 0.4072084560734708,
#   'unknown': 3.9040027724831052,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'nuclear'},
#  {'region': 'ap-northeast-3',
#   'name': 'Osaka',
#   'lat': '34.69',
#   'lon': '135.49',
#   'nuclear': 35.000833750208436,
#   'geothermal': 0.00833750208437552,
#   'biomass': 0.4418876104719026,
#   'coal': 22.494580623645156,
#   'wind': 0.13340003335000833,
#   'solar': 0.625312656328164,
#   'hydro': 8.379189594797399,
#   'gas': 24.81240620310155,
#   'oil': 3.1098882774720695,
#   'unknown': 1.6424879106219776,
#   'hydro discharge': 3.3516758379189597,
#   'battery discharge': 0.0,
#   'highest_source': 'nuclear'},
#  {'region': 'ap-south-1',
#   'name': 'Mumbai',
#   'lat': '19.08',
#   'lon': '72.88',
#   'nuclear': 3.2289888660956167,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 93.83642086471758,
#   'wind': 0.18165019809267294,
#   'solar': 0.0,
#   'hydro': 2.0059819289371896,
#   'gas': 0.7469581421569396,
#   'oil': 0.0,
#   'unknown': 0.0,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'coal'},
#  {'region': 'ca-central-1',
#   'name': 'Canada Central',
#   'lat': '45.5',
#   'lon': '-73.6',
#   'nuclear': 0.5438182780692045,
#   'geothermal': 0.0,
#   'biomass': 2.425525771211319,
#   'coal': 0.03850040906684633,
#   'wind': 6.886760671832139,
#   'solar': 0.0,
#   'hydro': 88.99850810914866,
#   'gas': 1.0587612493382743,
#   'oil': 0.0,
#   'unknown': 0.05293806246691372,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'hydro'},
#  {'region': 'ap-east-1',
#   'name': 'Hong Kong',
#   'lat': '22.27',
#   'lon': '114.16',
#   'nuclear': 28.01177536231884,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 24.003623188405797,
#   'wind': 0.0,
#   'solar': 0.0,
#   'hydro': 0.0,
#   'gas': 48.007246376811594,
#   'oil': 0.0,
#   'unknown': 0.0,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'gas'},
#  {'region': 'me-south-1',
#   'name': 'Bahrain',
#   'lat': '26.10',
#   'lon': '50.46',
#   'nuclear': 0.0,
#   'geothermal': 0.0,
#   'biomass': 0.0,
#   'coal': 0.0,
#   'wind': 0.0,
#   'solar': 0.0,
#   'hydro': 0.0,
#   'gas': 0.0,
#   'oil': 0.0,
#   'unknown': 100.0,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'unknown'},
#  {'region': 'af-south-1',
#   'name': 'South Africa',
#   'lat': '-33.93',
#   'lon': '18.42',
#   'nuclear': 4.310432569974554,
#   'geothermal': 0.0,
#   'biomass': 0.16284987277353688,
#   'coal': 87.35368956743002,
#   'wind': 8.173027989821884,
#   'solar': 0.0,
#   'hydro': 0.0,
#   'gas': 0.0,
#   'oil': 0.0,
#   'unknown': 0.0,
#   'hydro discharge': 0.0,
#   'battery discharge': 0.0,
#   'highest_source': 'coal'}]

# %% [markdown]
# ## Plot the data with Folium

# %%
import folium

# %%
map = folium.Map(tiles="OpenStreetMap", location=[31.8,0], zoom_start=2.2)

# %%
for region in data:
    highest_source = region['highest_source']
    if highest_source in ('gas', 'coal', 'oil', 'battery discharge'):
        colour = 'red'
    elif highest_source == 'nuclear':
        colour = 'orange'
    elif highest_source in ('hydro', 'biomass', 'solar', 'wind', 'geothermal', 'hydro discharge'):
        colour = 'green'
    else:
        colour = 'gray'

    energy_pct = round(float(region[highest_source]), 2)

    text = f'{region["region"]} ({region["name"]}): {highest_source} ({energy_pct}%)'
    
    marker = folium.Marker(
        location=(region['lat'], region['lon']),
        popup=text,
        icon=folium.Icon(color=colour)
    )
    
    map.add_child(marker)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7343215f38a6fa8c3471566f3c00dea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7343215f38a6fa8c3471566f3c00dea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7343215f38a6fa8c3471566f3c00dea = L.map(
#                 &quot;map_d7343215f38a6fa8c3471566f3c00dea&quot;,
#                 {
#                     center: [31.8, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f39214be5e940b1556a50226991cf62e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f39214be5e940b1556a50226991cf62e.addTo(map_d7343215f38a6fa8c3471566f3c00dea);
#
#
#             var marker_b1c9dbb85ee114813b454fc0de75ba5b = L.marker(
#                 [38.13, -78.45],
#                 {}
#             ).addTo(map_d7343215f38a6fa8c3471566f3c00dea);
#
#
#             var icon_13c145a605e23f17d2f97dfda813ca22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b1c9dbb85ee114813b454fc0de75ba5b.setIcon(icon_13c145a605e23f17d2f97dfda813ca22);
#
#
#         var popup_2f6d5fac000c27a58bd31ebc2155e85b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3388b37992c86bb2febc94461282eecd = $(`&lt;div id=&quot;html_3388b37992c86bb2febc94461282eecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;us-east-1 (Virginia): gas (42.71%)&lt;/div&gt;`)[0];
#                 popup_2f6d5fac000c27a58bd31ebc2155e85b.setContent(html_3388b37992c86bb2febc94461282eecd);
#
#
#
#         marker_b1c9dbb85ee114813b454fc0de75ba5b.bindPopup(popup_2f6d5fac000c27a58bd31ebc2155e85b)
#         ;
#
#
#
#
#             var marker_08b3c6bd1e340caf98b77c002443e85e = L.marker(
#                 [39.96, -83.0],
#                 {}
#             ).addTo(map_d7343215f38a6fa8c3471566f3c00dea);
#
#
#             var icon_161989f0499a8cb331e4d8a5e20fcf27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_08b3c6bd1e340caf98b77c002443e85e.setIcon(icon_161989f0499a8cb331e4d8a5e20fcf27);
#
#
#         var popup_c34e12d756f7724a81f757edb1908444 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d24613158c2c4fc667df2fd765a4dd47 = $(`&lt;div id=&quot;html_d24613158c2c4fc667df2fd765a4dd47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;us-east-2 (Ohio): gas (42.71%)&lt;/div&gt;`)[0];
#                 popup_c34e12d756f7724a81f757edb1908444.setContent(html_d24613158c2c4fc667df2fd765a4dd47);
#
#
#
#         marker_08b3c6bd1e340caf98b77c002443e85e.bindPopup(popup_c34e12d756f7724a81f757edb1908444)
#         ;
#
#
#
#
#             var marker_767b300985150950c2b5539cb1439b47 = L.marker(
#                 [59.25, 17.81],
#                 {}
#             ).addTo(map_d7343215f38a6fa8c3471566f3c00dea);
#
#
#             var icon_ab86d847fe5fe685302bbbbf39b9e7ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_767b300985150950c2b5539cb1439b47.setIcon(icon_ab86d847fe5fe685302bbbbf39b9e7ca);
#
#
#         var popup_e3009317f3c608d928e86b7ec7702f0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95f69bf9604ea9ba91a58bafef4566c7 = $(`&lt;div id=&quot;html_95f69bf9604ea9ba91a58bafef4566c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;eu-north-1 (Stockholm): nuclear (70.36%)&lt;/div&gt;`)[0];
#                 popup_e3009317f3c608d928e86b7ec7702f0b.setContent(html_95f69bf9604ea9ba91a58bafef4566c7);
#
#
#
#         marker_767b300985150950c2b5539cb1439b47.bindPopup(popup_e3009317f3c608d928e86b7ec7702f0b)
#         ;
#
#
#
#
#             var marker_97a7645aa9cc6f1a06fa32d1af58c040 = L.marker(
#                 [45.43, 9.29],
#                 {}
#             ).addTo(map_d7343215f38a6fa8c3471566f3c00dea);
#
#
#             var icon_345837bc3c2f3b758307ca3949076696 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;:
